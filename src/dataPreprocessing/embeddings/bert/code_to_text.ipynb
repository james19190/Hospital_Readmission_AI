# %%
diagnosis_code_to_description = {
    'd_001': 'CHOLERA',
    'd_002': 'TYPHOID AND PARATYPHOID FEVERS',
    'd_003': 'OTHER SALMONELLA INFECTIONS',
    'd_004': 'SHIGELLOSIS',
    'd_005': 'OTHER FOOD POISONING (BACTERIAL)',
    'd_006': 'AMOEBIASIS',
    'd_007': 'OTHER PROTOZOAL INTESTINAL DISEASES',
    'd_008': 'INTESTINAL INFECTIONS DUE TO OTHER ORGANISMS',
    'd_009': 'ILL-DEFINED INTESTINAL INFECTIONS',
    'd_010': 'TUBERCULOSIS',
    'd_011': 'PULMONARY TUBERCULOSIS',
    'd_012': 'OTHER RESPIRATORY TUBERCULOSIS',
    'd_013': 'TUBERCULOSIS OF MENINGES AND CENTRAL NERVOUS SYSTEM',
    'd_014': 'TUBERCULOSIS OF INTESTINES, PERITONEUM AND MESENTERIC GLANDS',
    'd_015': 'TUBERCULOSIS OF BONES AND JOINTS',
    'd_016': 'TUBERCULOSIS OF GENITOURINARY SYSTEM',
    'd_017': 'TUBERCULOSIS OF OTHER ORGANS',
    'd_018': 'MILIARY TUBERCULOSIS',
    'd_020': 'ZOONOTIC BACTERIAL DISEASE',
    'd_021': 'TULARAEMIA',
    'd_022': 'ANTHRAX',
    'd_023': 'BRUCELLOSIS',
    'd_024': 'GLANDERS',
    'd_025': 'MELIOIDOSIS',
    'd_026': 'RAT-BITE FEVER',
    'd_027': 'OTHER ZOONOTIC BACTERIAL DISEASES',
    'd_030': 'OTHER BACTERIAL DISEASES',
    'd_031': 'DISEASES DUE TO OTHER MYCOBACTERIA',
    'd_032': 'DIPHTHERIA',
    'd_033': 'WHOOPING COUGH',
    'd_034': 'STREPTOCOCCAL SORE THROAT AND SCARLATINA',
    'd_035': 'ERYSIPELAS',
    'd_036': 'MENINGOCOCCAL INFECTION',
    'd_037': 'TETANUS',
    'd_038': 'SEPTICAEMIA',
    'd_039': 'ACTINOMYCOTIC INFECTIONS',
    'd_040': 'OTHER BACTERIAL DISEASES',
    'd_041': 'BACTERIAL INFECTION IN CONDITIONS CLASSIFIED ELSEWHERE AND OF UNSPECIFIED SITE',
    'd_042': 'HUMAN IMMUNODEFICIENCY VIRUS (HIV) INFECTION WITH SPECIFIED CONDITIONS',
    'd_043': 'HUMAN IMMUNODEFICIENCY VIRUS (HIV) INFECTION CAUSING SPECIFIED CONDITIONS',
    'd_044': 'OTHER HUMAN IMMUNODEFICIENCY VIRUS (HIV) INFECTION',
    'd_045': 'ACUTE POLIOMYELITIS',
    'd_046': 'SLOW VIRUS INFECTION OF CENTRAL NERVOUS SYSTEM',
    'd_047': 'MENINGITIS DUE TO ENTEROVIRUS',
    'd_048': 'OTHER ENTEROVIRUS DISEASES OF CENTRAL NERVOUS SYSTEM',
    'd_049': 'OTHER NON-ARTHROPOD-BORNE VIRAL DISEASES OF CENTRAL NERVOUS SYSTEM',
    'd_050': 'SMALLPOX',
    'd_051': 'COWPOX AND PARAVACCINIA',
    'd_052': 'CHICKENPOX',
    'd_053': 'HERPES ZOSTER',
    'd_054': 'HERPES SIMPLEX',
    'd_055': 'MEASLES',
    'd_056': 'RUBELLA',
    'd_057': 'OTHER VIRAL EXANTHEMATA',
    'd_060': 'YELLOW FEVER',
    'd_061': 'DENGUE',
    'd_062': 'MOSQUITO-BORNE VIRAL ENCEPHALITIS',
    'd_063': 'TICK-BORNE VIRAL ENCEPHALITIS',
    'd_064': 'VIRAL ENCEPHALITIS TRANSMITTED BY OTHER AND UNSPECIFIED ARTHROPODS',
    'd_065': 'ARTHROPOD-BORNE HAEMORRHAGIC FEVER',
    'd_066': 'OTHER ARTHROPOD-BORNE VIRAL DISEASES',
    'd_070': 'VIRAL HEPATITIS',
    'd_071': 'RABIES',
    'd_072': 'MUMPS',
    'd_073': 'ORNITHOSIS',
    'd_074': 'SPECIFIC DISEASES DUE TO COXSACKIE VIRUS',
    'd_075': 'INFECTIOUS MONONUCLEOSIS',
    'd_076': 'TRACHOMA',
    'd_077': 'OTHER DISEASES OF CONJUNCTIVA DUE TO VIRUSES AND CHLAMYDIAE',
    'd_078': 'OTHER DISEASES DUE TO VIRUSES AND CHLAMYDIAE',
    'd_079': 'VIRAL INFECTION IN CONDITIONS CLASSIFIED ELSEWHERE AND OF UNSPECIFIED SITE',
    'd_080': 'LOUSE-BORNE (EPIDEMIC) TYPHUS',
    'd_081': 'OTHER TYPHUS',
    'd_082': 'TICK-BORNE RICKETTSIOSES',
    'd_083': 'OTHER RICKETTSIOSES',
    'd_084': 'MALARIA',
    'd_085': 'LEISHMANIASIS',
    'd_086': 'TRYPANOSOMIASIS',
    'd_087': 'RELAPSING FEVER',
    'd_088': 'OTHER ARTHROPOD-BORNE DISEASES',
    'd_090': 'CONGENITAL SYPHILIS',
    'd_091': 'EARLY SYPHILIS, SYMPTOMATIC',
    'd_092': 'EARLY SYPHILIS, LATENT',
    'd_093': 'CARDIOVASCULAR SYPHILIS',
    'd_094': 'NEUROSYPHILIS',
    'd_095': 'OTHER FORMS OF LATE SYPHILIS, WITH SYMPTOMS',
    'd_096': 'LATE SYPHILIS, LATENT',
    'd_097': 'OTHER AND UNSPECIFIED SYPHILIS',
    'd_098': 'GONOCOCCAL INFECTIONS',
    'd_099': 'OTHER VENEREAL DISEASES',
    'd_100': 'LEPTOSPIROSIS',
    'd_101': "VINCENT'S ANGINA",
    'd_102': 'YAWS',
    'd_103': 'PINTA',
    'd_104': 'OTHER SPIROCHAETAL INFECTION',
    'd_110': 'DERMATOPHYTOSIS',
    'd_111': 'DERMATOMYCOSIS, OTHER AND UNSPECIFIED',
    'd_112': 'CANDIDIASIS',
    'd_114': 'COCCIDIOIDOMYCOSIS',
    'd_115': 'HISTOPLASMOSIS',
    'd_116': 'BLASTOMYCOTIC INFECTION',
    'd_117': 'OTHER MYCOSES',
    'd_118': 'OPPORTUNISTIC MYCOSES',
    'd_120': 'SCHISTOSOMIASIS (BILHARZIASIS)',
    'd_121': 'OTHER TREMATODE INFECTIONS',
    'd_122': 'ECHINOCOCCOSIS',
    'd_123': 'OTHER CESTODE INFECTION',
    'd_124': 'TRICHINOSIS',
    'd_125': 'FILARIAL INFECTION AND DRACONTIASIS',
    'd_126': 'ANCYLOSTOMIASIS AND NECATORIASIS',
    'd_127': 'OTHER INTESTINAL HELMINTHIASES',
    'd_128': 'OTHER AND UNSPECIFIED HELMINTHIASES',
    'd_129': 'INTESTINAL PARASITISM, UNSPECIFIED',
    'd_130': 'TOXOPLASMOSIS',
    'd_131': 'TRICHOMONIASIS',
    'd_132': 'PEDICULOSIS AND PHTHIRUS INFESTATION',
    'd_133': 'ACARIASIS',
    'd_134': 'OTHER INFESTATION',
    'd_135': 'SARCOIDOSIS',
    'd_136': 'OTHER AND UNSPECIFIED INFECTIOUS AND PARASITIC DISEASES',
    'd_137': 'LATE EFFECTS OF TUBERCULOSIS',
    'd_138': 'LATE EFFECTS OF ACUTE POLIOMYELITIS',
    'd_139': 'LATE EFFECTS OF OTHER AND UNSPECIFIED INFECTIOUS AND PARASITIC DISEASES',
    'd_140': 'MALIGNANT NEOPLASM OF LIP, ORAL CAVITY AND PHARYNX',
    'd_141': 'MALIGNANT NEOPLASM OF TONGUE',
    'd_142': 'MALIGNANT NEOPLASM OF MAJOR SALIVARY GLANDS',
    'd_143': 'MALIGNANT NEOPLASM OF GUM',
    'd_144': 'MALIGNANT NEOPLASM OF FLOOR OF MOUTH',
    'd_145': 'MALIGNANT NEOPLASM OF OTHER AND UNSPECIFIED PARTS OF MOUTH',
    'd_146': 'MALIGNANT NEOPLASM OF OROPHARYNX',
    'd_147': 'MALIGNANT NEOPLASM OF NASOPHARYNX',
    'd_148': 'MALIGNANT NEOPLASM OF HYPOPHARYNX',
    'd_149': 'MALIGNANT NEOPLASM OF OTHER AND ILL-DEFINED SITES WITHIN THE LIP, ORAL CAVITY AND PHARYNX',
    'd_150': 'MALIGNANT NEOPLASM OF OESOPHAGUS',
    'd_151': 'MALIGNANT NEOPLASM OF STOMACH',
    'd_152': 'MALIGNANT NEOPLASM OF SMALL INTESTINE, INCLUDING DUODENUM',
    'd_153': 'MALIGNANT NEOPLASM OF COLON',
    'd_154': 'MALIGNANT NEOPLASM OF RECTUM, RECTOSIGMOID JUNCTION AND ANUS',
    'd_155': 'MALIGNANT NEOPLASM OF LIVER AND INTRAHEPATIC BILE DUCTS',
    'd_156': 'MALIGNANT NEOPLASM OF GALLBLADDER AND EXTRAHEPATIC BILE DUCTS',
    'd_157': 'MALIGNANT NEOPLASM OF PANCREAS',
    'd_158': 'MALIGNANT NEOPLASM OF RETROPERITONEUM AND PERITONEUM',
    'd_159': 'MALIGNANT NEOPLASM OF OTHER AND ILL-DEFINED SITES WITHIN THE DIGESTIVE ORGANS AND PERITONEUM',
    'd_160': 'MALIGNANT NEOPLASM OF NASAL CAVITIES, MIDDLE EAR AND ACCESSORY SINUSES',
    'd_161': 'MALIGNANT NEOPLASM OF LARYNX',
    'd_162': 'MALIGNANT NEOPLASM OF TRACHEA, BRONCHUS AND LUNG',
    'd_163': 'MALIGNANT NEOPLASM OF PLEURA',
    'd_164': 'MALIGNANT NEOPLASM OF THYMUS, HEART AND MEDIASTINUM',
    'd_165': 'MALIGNANT NEOPLASM OF OTHER AND ILL-DEFINED SITES WITHIN THE RESPIRATORY SYSTEM AND INTRATHORACIC ORGANS',
    'd_170': 'MALIGNANT NEOPLASM OF BONE AND ARTICULAR CARTILAGE',
    'd_171': 'MALIGNANT NEOPLASM OF CONNECTIVE AND OTHER SOFT TISSUE',
    'd_172': 'MALIGNANT MELANOMA OF SKIN',
    'd_173': 'OTHER MALIGNANT NEOPLASM OF SKIN',
    'd_174': 'MALIGNANT NEOPLASM OF FEMALE BREAST',
    'd_175': 'MALIGNANT NEOPLASM OF MALE BREAST',
    'd_179': 'MALIGNANT NEOPLASM OF UTERUS, PART UNSPECIFIED',
    'd_180': 'MALIGNANT NEOPLASM OF CERVIX UTERI',
    'd_181': 'MALIGNANT NEOPLASM OF PLACENTA',
    'd_182': 'MALIGNANT NEOPLASM OF BODY OF UTERUS',
    'd_183': 'MALIGNANT NEOPLASM OF OVARY AND OTHER UTERINE ADNEXA',
    'd_184': 'MALIGNANT NEOPLASM OF OTHER AND UNSPECIFIED FEMALE GENITAL ORGANS',
    'd_185': 'MALIGNANT NEOPLASM OF PROSTATE',
    'd_186': 'MALIGNANT NEOPLASM OF TESTIS',
    'd_187': 'MALIGNANT NEOPLASM OF PENIS AND OTHER MALE GENITAL ORGANS',
    'd_188': 'MALIGNANT NEOPLASM OF BLADDER',
    'd_189': 'MALIGNANT NEOPLASM OF KIDNEY AND OTHER AND UNSPECIFIED URINARY',
    'd_190': 'MALIGNANT NEOPLASM OF EYE',
    'd_191': 'MALIGNANT NEOPLASM OF BRAIN',
    'd_192': 'MALIGNANT NEOPLASM OF OTHER AND UNSPECIFIED PARTS OF NERVOUS SYSTEM',
    'd_193': 'MALIGNANT NEOPLASM OF THYROID GLAND',
    'd_194': 'MALIGNANT NEOPLASM OF OTHER ENDOCRINE GLANDS AND RELATED STRUCTURES',
    'd_195': 'MALIGNANT NEOPLASM OF OTHER AND ILL-DEFINED SITES',
    'd_196': 'SECONDARY AND UNSPECIFIED MALIGNANT NEOPLASM OF LYMPH NODES',
    'd_197': 'SECONDARY MALIGNANT NEOPLASM OF RESPIRATORY AND DIGESTIVE SYSTEMS',
    'd_198': 'SECONDARY MALIGNANT NEOPLASM OF OTHER SPECIFIED SITES',
    'd_199': 'MALIGNANT NEOPLASM WITHOUT SPECIFICATION OF SITE',
    'd_200': 'LYMPHOSARCOMA AND RETICULOSARCOMA',
    'd_201': "HODGKIN'S DISEASE",
    'd_202': 'OTHER MALIGNANT NEOPLASM OF LYMPHOID AND HISTIOCYTIC TISSUE',
    'd_203': 'MULTIPLE MYELOMA AND IMMUNOPROLIFERATIVE NEOPLASMS',
    'd_204': 'LYMPHOID LEUKAEMIA',
    'd_205': 'MYELOID LEUKAEMIA',
    'd_206': 'MONOCYTIC LEUKAEMIA',
    'd_207': 'OTHER SPECIFIED LEUKAEMIA',
    'd_208': 'LEUKAEMIA OF UNSPECIFIED CELL TYPE',
    'd_210': 'BENIGN NEOPLASM OF LIP, ORAL CAVITY AND PHARYNX',
    'd_211': 'BENIGN NEOPLASM OF OTHER PARTS OF DIGESTIVE SYSTEM',
    'd_212': 'BENIGN NEOPLASM OF RESPIRATORY AND INTRATHORACIC ORGANS',
    'd_213': 'BENIGN NEOPLASM OF BONE AND ARTICULAR CARTILAGE',
    'd_214': 'LIPOMA',
    'd_215': 'OTHER BENIGN NEOPLASM OF CONNECTIVE AND OTHER SOFT TISSUE',
    'd_216': 'BENIGN NEOPLASM OF SKIN',
    'd_217': 'BENIGN NEOPLASM OF BREAST',
    'd_218': 'UTERINE LEIOMYOMA',
    'd_219': 'OTHER BENIGN NEOPLASM OF UTERUS',
    'd_220': 'BENIGN NEOPLASM OF OVARY',
    'd_221': 'BENIGN NEOPLASM OF OTHER FEMALE GENITAL ORGANS',
    'd_222': 'BENIGN NEOPLASM OF MALE GENITAL ORGANS',
    'd_223': 'BENIGN NEOPLASM OF KIDNEY AND OTHER URINARY ORGANS',
    'd_224': 'BENIGN NEOPLASM OF EYE',
    'd_225': 'BENIGN NEOPLASM OF BRAIN AND OTHER PARTS OF NERVOUS SYSTEM',
    'd_226': 'BENIGN NEOPLASM OF THYROID GLAND',
    'd_227': 'BENIGN NEOPLASM OF OTHER ENDOCRINE GLANDS AND RELATED STRUCTURES',
    'd_228': 'HAEMANGIOMA AND LYMPHANGIOMA, ANY SITE',
    'd_229': 'BENIGN NEOPLASM OF OTHER AND UNSPECIFIED SITES',
    'd_230': 'CARCINOMA IN SITU OF DIGESTIVE ORGANS',
    'd_231': 'CARCINOMA IN SITU OF RESPIRATORY SYSTEM',
    'd_232': 'CARCINOMA IN SITU OF SKIN',
    'd_233': 'CARCINOMA IN SITU OF BREAST AND GENITOURINARY SYSTEM',
    'd_234': 'CARCINOMA IN SITU OF OTHER AND UNSPECIFIED SITES',
    'd_235': 'NEOPLASM OF UNCERTAIN BEHAVIOUR OF DIGESTIVE AND RESPIRATORY SYSTEMS',
    'd_236': 'NEOPLASM OF UNCERTAIN BEHAVIOUR OF GENITOURINARY ORGANS',
    'd_237': 'NEOPLASM OF UNCERTAIN BEHAVIOUR OF ENDOCRINE GLANDS AND NERVOUS SYSTEM',
    'd_238': 'NEOPLASM OF UNCERTAIN BEHAVIOUR OF OTHER AND UNSPECIFIED SITES',
    'd_239': 'NEOPLASM OF UNSPECIFIED NATURE',
    'd_280': 'IRON DEFICIENCY ANAEMIAS',
    'd_281': 'OTHER DEFICIENCY ANAEMIAS',
    'd_282': 'HEREDITARY HAEMOLYTIC ANAEMIAS',
    'd_283': 'ACQUIRED HAEMOLYTIC ANAEMIAS',
    'd_284': 'APLASTIC ANAEMIA',
    'd_285': 'OTHER AND UNSPECIFIED ANAEMIAS',
    'd_286': 'COAGULATION DEFECTS',
    'd_287': 'PURPURA AND OTHER HAEMORRHAGIC CONDITIONS',
    'd_288': 'DISEASES OF WHITE BLOOD CELLS',
    'd_289': 'OTHER DISEASES OF BLOOD AND BLOOD-FORMING ORGANS',
    'd_290': 'SENILE AND PRESENILE ORGANIC PSYCHOTIC CONDITIONS',
    'd_291': 'ALCOHOLIC PSYCHOSES',
    'd_292': 'DRUG PSYCHOSES',
    'd_293': 'TRANSIENT ORGANIC PSYCHOTIC CONDITIONS',
    'd_294': 'OTHER ORGANIC PSYCHOTIC CONDITIONS (CHRONIC)',
    'd_295': 'SCHIZOPHRENIC PSYCHOSES',
    'd_296': 'AFFECTIVE PSYCHOSES',
    'd_297': 'PARANOID STATES',
    'd_298': 'OTHER NONORGANIC PSYCHOSES',
    'd_299': 'PSYCHOSES WITH ORIGIN SPECIFIC TO CHILDHOOD',
    'd_300': 'NEUROTIC DISORDERS',
    'd_301': 'PERSONALITY DISORDERS',
    'd_302': 'SEXUAL DEVIATIONS AND DISORDERS',
    'd_303': 'ALCOHOL DEPENDENCE SYNDROME',
    'd_304': 'DRUG DEPENDENCE',
    'd_305': 'NONDEPENDENT ABUSE OF DRUGS',
    'd_306': 'PHYSIOLOGICAL MALFUNCTION ARISING FROM MENTAL FACTORS',
    'd_307': 'SPECIAL SYMPTOMS OR SYNDROMES NOT ELSEWHERE CLASSIFIED',
    'd_308': 'ACUTE REACTION TO STRESS',
    'd_309': 'ADJUSTMENT REACTION',
    'd_310': 'SPECIFIC NONPSYCHOTIC MENTAL DISORDERS FOLLOWING ORGANIC BRAIN DAMAGE',
    'd_311': 'DEPRESSIVE DISORDER, NOT ELSEWHERE CLASSIFIED',
    'd_312': 'DISTURBANCE OF CONDUCT NOT ELSEWHERE CLASSIFIED',
    'd_313': 'DISTURBANCE OF EMOTIONS SPECIFIC TO CHILDHOOD AND ADOLESCENCE',
    'd_314': 'HYPERKINETIC SYNDROME OF CHILDHOOD',
    'd_315': 'SPECIFIC DELAYS IN DEVELOPMENT',
    'd_316': 'PSYCHIC FACTORS ASSOCIATED WITH DISEASES CLASSIFIED ELSEWHERE',
    'd_317': 'MILD MENTAL RETARDATION',
    'd_318': 'OTHER SPECIFIED MENTAL RETARDATION',
    'd_319': 'UNSPECIFIED MENTAL RETARDATION',
    'd_320': 'BACTERIAL MENINGITIS',
    'd_321': 'MENINGITIS DUE TO OTHER ORGANISMS',
    'd_322': 'MENINGITIS OF UNSPECIFIED CAUSE',
    'd_323': 'ENCEPHALITIS, MYELITIS AND ENCEPHALOMYELITIS',
    'd_324': 'INTRACRANIAL AND INTRASPINAL ABSCESS',
    'd_325': 'PHLEBITIS AND THROMBOPHLEBITIS OF INTRACRANIAL VENOUS SINUSES',
    'd_326': 'LATE EFFECTS OF INTRACRANIAL ABSCESS OR PYOGENIC INFECTION',
    'd_330': 'CEREBRAL DEGENERATIONS USUALLY MANIFEST IN CHILDHOOD',
    'd_331': 'OTHER CEREBRAL DEGENERATIONS',
    'd_332': "PARKINSON'S DISEASE",
    'd_333': 'OTHER EXTRAPYRAMIDAL DISEASE AND ABNORMAL MOVEMENT DISORDERS',
    'd_334': 'SPINOCEREBELLAR DISEASE',
    'd_335': 'ANTERIOR HORN CELL DISEASE',
    'd_336': 'OTHER DISEASES OF SPINAL CORD',
    'd_337': 'DISORDERS OF THE AUTONOMIC NERVOUS SYSTEM',
    'd_340': 'MULTIPLE SCLEROSIS',
    'd_341': 'OTHER DEMYELINATING DISEASES OF CENTRAL NERVOUS SYSTEM',
    'd_342': 'HEMIPLEGIA',
    'd_343': 'INFANTILE CEREBRAL PALSY',
    'd_344': 'OTHER PARALYTIC SYNDROMES',
    'd_345': 'EPILEPSY',
    'd_346': 'MIGRAINE',
    'd_347': 'CATAPLEXY AND NARCOLEPSY',
    'd_348': 'OTHER CONDITIONS OF BRAIN',
    'd_349': 'OTHER AND UNSPECIFIED DISORDERS OF THE NERVOUS SYSTEM',
    'd_350': 'TRIGEMINAL NERVE DISORDERS',
    'd_351': 'FACIAL NERVE DISORDERS',
    'd_352': 'DISORDERS OF OTHER CRANIAL NERVES',
    'd_353': 'NERVE ROOT AND PLEXUS DISORDERS',
    'd_354': 'MONONEURITIS OF UPPER LIMB AND MONONEURITIS MULTIPLEX',
    'd_355': 'MONONEURITIS OF LOWER LIMB',
    'd_356': 'HEREDITARY AND IDIOPATHIC PERIPHERAL NEUROPATHY',
    'd_357': 'INFLAMMATORY AND TOXIC NEUROPATHY',
    'd_358': 'MYONEURAL DISORDERS',
    'd_359': 'MUSCULAR DYSTROPHIES AND OTHER MYOPATHIES',
    'd_360': 'DISORDERS OF THE GLOBE',
    'd_361': 'RETINAL DETACHMENTS AND DEFECTS',
    'd_362': 'OTHER RETINAL DISORDERS',
    'd_363': 'CHORIORETINAL INFLAMMATIONS AND SCARS AND OTHER DISORDERS OF CHOROID',
    'd_364': 'DISORDERS OF IRIS AND CILIARY BODY',
    'd_365': 'GLAUCOMA',
    'd_366': 'CATARACT',
    'd_367': 'DISORDERS OF REFRACTION AND ACCOMMODATION',
    'd_368': 'VISUAL DISTURBANCES',
    'd_369': 'BLINDNESS AND LOW VISION',
    'd_370': 'KERATITIS',
    'd_371': 'CORNEAL OPACITY AND OTHER DISORDERS OF CORNEA',
    'd_372': 'DISORDERS OF CONJUNCTIVA',
    'd_373': 'INFLAMMATION OF EYELIDS',
    'd_374': 'OTHER DISORDERS OF EYELIDS',
    'd_375': 'DISORDERS OF LACRIMAL SYSTEM',
    'd_376': 'DISORDERS OF THE ORBIT',
    'd_377': 'DISORDERS OF OPTIC NERVE AND VISUAL PATHWAYS',
    'd_378': 'STRABISMUS AND OTHER DISORDERS OF BINOCULAR EYE MOVEMENTS',
    'd_379': 'OTHER DISORDERS OF EYE',
    'd_380': 'DISORDERS OF EXTERNAL EAR',
    'd_381': 'NONSUPPURATIVE OTITIS MEDIA AND EUSTACHIAN TUBE DISORDERS',
    'd_382': 'SUPPURATIVE AND UNSPECIFIED OTITIS MEDIA',
    'd_383': 'MASTOIDITIS AND RELATED CONDITIONS',
    'd_384': 'OTHER DISORDERS OF TYMPANIC MEMBRANE',
    'd_385': 'OTHER DISORDERS OF MIDDLE EAR AND MASTOID',
    'd_386': 'VERTIGINOUS SYNDROMES AND OTHER DISORDERS OF VESTIBULAR SYSTEM',
    'd_387': 'OTOSCLEROSIS',
    'd_388': 'OTHER DISORDERS OF EAR',
    'd_389': 'DEAFNESS',
    'd_390': 'RHEUMATIC FEVER WITHOUT MENTION OF HEART INVOLVEMENT',
    'd_391': 'RHEUMATIC FEVER WITH HEART INVOLVEMENT',
    'd_392': 'RHEUMATIC CHOREA',
    'd_393': 'CHRONIC RHEUMATIC PERICARDITIS',
    'd_394': 'DISEASES OF MITRAL VALVE',
    'd_395': 'DISEASES OF AORTIC VALVE',
    'd_396': 'DISEASES OF MITRAL AND AORTIC VALVES',
    'd_397': 'DISEASES OF OTHER ENDOCARDIAL STRUCTURES',
    'd_398': 'OTHER RHEUMATIC HEART DISEASE',
    'd_401': 'ESSENTIAL HYPERTENSION',
    'd_402': 'HYPERTENSIVE HEART DISEASE',
    'd_403': 'HYPERTENSIVE RENAL DISEASE',
    'd_404': 'HYPERTENSIVE HEART AND RENAL DISEASE',
    'd_405': 'SECONDARY HYPERTENSION',
    'd_410': 'ACUTE MYOCARDIAL INFARCTION',
    'd_411': 'OTHER ACUTE AND SUBACUTE FORMS OF ISCHAEMIC HEART DISEASE',
    'd_412': 'OLD MYOCARDIAL INFARCTION',
    'd_413': 'ANGINA PECTORIS',
    'd_414': 'OTHER FORMS OF CHRONIC ISCHAEMIC HEART DISEASE',
    'd_415': 'ACUTE PULMONARY HEART DISEASE',
    'd_416': 'CHRONIC PULMONARY HEART DISEASE',
    'd_417': 'OTHER DISEASES OF PULMONARY CIRCULATION',
    'd_420': 'ACUTE PERICARDITIS',
    'd_421': 'ACUTE AND SUBACUTE ENDOCARDITIS',
    'd_422': 'ACUTE MYOCARDITIS',
    'd_423': 'OTHER DISEASES OF PERICARDIUM',
    'd_424': 'OTHER DISEASES OF ENDOCARDIUM',
    'd_425': 'CARDIOMYOPATHY',
    'd_426': 'CONDUCTION DISORDERS',
    'd_427': 'CARDIAC DYSRHYTHMIAS',
    'd_428': 'HEART FAILURE',
    'd_429': 'ILL-DEFINED DESCRIPTIONS AND COMPLICATIONS OF HEART DISEASE',
    'd_430': 'SUBARACHNOID HAEMORRHAGE',
    'd_431': 'INTRACEREBRAL HAEMORRHAGE',
    'd_432': 'OTHER AND UNSPECIFIED INTRACRANIAL HAEMORRHAGE',
    'd_433': 'OCCLUSION AND STENOSIS OF PRECEREBRAL ARTERIES',
    'd_434': 'OCCLUSION OF CEREBRAL ARTERIES',
    'd_435': 'TRANSIENT CEREBRAL ISCHAEMIA',
    'd_436': 'ACUTE BUT ILL-DEFINED CEREBROVASCULAR DISEASE',
    'd_437': 'OTHER AND ILL-DEFINED CEREBROVASCULAR DISEASE',
    'd_438': 'LATE EFFECTS OF CEREBROVASCULAR DISEASE',
    'd_440': 'ATHEROSCLEROSIS',
    'd_441': 'AORTIC ANEURYSM',
    'd_442': 'OTHER ANEURYSM',
    'd_443': 'OTHER PERIPHERAL VASCULAR DISEASE',
    'd_444': 'ARTERIAL EMBOLISM AND THROMBOSIS',
    'd_446': 'POLYARTERITIS NODOSA AND ALLIED CONDITIONS',
    'd_447': 'OTHER DISORDERS OF ARTERIES AND ARTERIOLES',
    'd_448': 'DISEASES OF CAPILLARIES',
    'd_451': 'PHLEBITIS AND THROMBOPHLEBITIS',
    'd_452': 'PORTAL VEIN THROMBOSIS',
    'd_453': 'OTHER VENOUS EMBOLISM AND THROMBOSIS',
    'd_454': 'VARICOSE VEINS OF LOWER EXTREMITIES',
    'd_455': 'HAEMORRHOIDS',
    'd_456': 'VARICOSE VEINS OF OTHER SITES',
    'd_457': 'NONSUPPURATIVE DISORDERS OF LYMPHATIC CHANNELS',
    'd_458': 'HYPOTENSION',
    'd_459': 'OTHER DISORDERS OF CIRCULATORY SYSTEM',
    'd_460': 'ACUTE NASOPHARYNGITIS (COMMON COLD)',
    'd_461': 'ACUTE SINUSITIS',
    'd_462': 'ACUTE PHARYNGITIS',
    'd_463': 'ACUTE TONSILLITIS',
    'd_464': 'ACUTE LARYNGITIS AND TRACHEITIS',
    'd_465': 'ACUTE UPPER RESPIRATORY INFECTIONS OF MULTIPLE OR UNSPECIFIED SITE',
    'd_466': 'ACUTE BRONCHITIS AND BRONCHIOLITIS',
    'd_470': 'DEFLECTED NASAL SEPTUM',
    'd_471': 'NASAL POLYPS',
    'd_472': 'CHRONIC PHARYNGITIS AND NASOPHARYNGITIS',
    'd_473': 'CHRONIC SINUSITIS',
    'd_474': 'CHRONIC DISEASE OF TONSILS AND ADENOIDS',
    'd_475': 'PERITONSILLAR ABSCESS',
    'd_476': 'CHRONIC LARYNGITIS AND LARYNGOTRACHEITIS',
    'd_477': 'ALLERGIC RHINITIS',
    'd_478': 'OTHER DISEASES OF UPPER RESPIRATORY TRACT',
    'd_480': 'VIRAL PNEUMONIA',
    'd_481': 'PNEUMOCOCCAL PNEUMONIA',
    'd_482': 'OTHER BACTERIAL PNEUMONIA',
    'd_483': 'PNEUMONIA DUE TO OTHER SPECIFIED ORGANISM',
    'd_484': 'PNEUMONIA IN INFECTIOUS DISEASES CLASSIFIED ELSEWHERE',
    'd_485': 'BRONCHOPNEUMONIA, ORGANISM UNSPECIFIED',
    'd_486': 'PNEUMONIA, ORGANISM UNSPECIFIED',
    'd_487': 'INFLUENZA',
    'd_490': 'BRONCHITIS, NOT SPECIFIED AS ACUTE OR CHRONIC',
    'd_491': 'CHRONIC BRONCHITIS',
    'd_492': 'EMPHYSEMA',
    'd_493': 'ASTHMA',
    'd_494': 'BRONCHIECTASIS',
    'd_495': 'EXTRINSIC ALLERGIC ALVEOLITIS',
    'd_496': 'CHRONIC AIRWAYS OBSTRUCTION, NOT ELSEWHERE CLASSIFIED',
    'd_500': "COALWORKERS' PNEUMOCONIOSIS",
    'd_501': 'ASBESTOSIS',
    'd_502': 'PNEUMOCONIOSIS DUE TO OTHER SILICA OR SILICATES',
    'd_503': 'PNEUMOCONIOSIS DUE TO OTHER INORGANIC DUST',
    'd_504': 'PNEUMOPATHY DUE TO INHALATION OF OTHER DUST',
    'd_505': 'PNEUMOCONIOSIS, UNSPECIFIED',
    'd_506': 'RESPIRATORY CONDITIONS DUE TO CHEMICAL FUMES AND VAPOURS',
    'd_507': 'PNEUMONITIS DUE TO SOLIDS AND LIQUIDS',
    'd_508': 'RESPIRATORY CONDITIONS DUE TO OTHER AND UNSPECIFIED EXTERNAL AGENTS',
    'd_509': 'UNSPECIFIED RESPIRATORY CONDITIONS',
    'd_510': 'EMPYEMA',
    'd_511': 'PLEURISY',
    'd_512': 'PNEUMOTHORAX',
    'd_513': 'ABSCESS OF LUNG AND MEDIASTINUM',
    'd_514': 'PULMONARY CONGESTION AND HYPOSTASIS',
    'd_515': 'POSTINFLAMMATORY PULMONARY FIBROSIS',
    'd_516': 'OTHER ALVEOLAR AND PARIETOALVEOLAR PNEUMOPATHY',
    'd_517': 'LUNG INVOLVEMENT IN CONDITIONS CLASSIFIED ELSEWHERE',
    'd_518': 'OTHER DISEASES OF LUNG',
    'd_519': 'OTHER DISEASES OF RESPIRATORY SYSTEM',
    'd_520': 'DISORDERS OF TOOTH DEVELOPMENT AND ERUPTION',
    'd_521': 'DISEASES OF HARD TISSUES OF TEETH',
    'd_522': 'DISEASES OF PULP AND PERIAPICAL TISSUES',
    'd_523': 'GINGIVAL AND PERIODONTAL DISEASES',
    'd_524': 'DENTOFACIAL ANOMALIES, INCLUDING MALOCCLUSION',
    'd_525': 'OTHER DISEASES AND CONDITIONS OF THE TEETH AND SUPPORTING STRUCTURES',
    'd_526': 'DISEASES OF THE JAWS',
    'd_527': 'DISEASES OF THE SALIVARY GLANDS',
    'd_528': 'DISEASES OF THE ORAL SOFT TISSUES, EXCLUDING LESIONS SPECIFIC FOR GINGIVA AND TONGUE',
    'd_529': 'DISEASES AND OTHER CONDITIONS OF THE TONGUE',
    'd_530': 'DISEASES OF OESOPHAGUS',
    'd_531': 'GASTRIC ULCER',
    'd_532': 'DUODENAL ULCER',
    'd_533': 'PEPTIC ULCER, SITE UNSPECIFIED',
    'd_534': 'GASTROJEJUNAL ULCER',
    'd_535': 'GASTRITIS AND DUODENITIS',
    'd_536': 'DISEASES OF FUNCTION OF STOMACH',
    'd_537': 'OTHER DISORDERS OF STOMACH AND DUODENUM',
    'd_540': 'ACUTE APPENDICITIS',
    'd_541': 'APPENDICITIS, UNQUALIFIED',
    'd_542': 'OTHER APPENDICITIS',
    'd_543': 'OTHER DISEASES OF APPENDIX',
    'd_550': 'INGUINAL HERNIA',
    'd_551': 'OTHER HERNIA OF ABDOMINAL CAVITY, WITH GANGRENE',
    'd_552': 'OTHER HERNIA OF ABDOMINAL CAVITY WITH OBSTRUCTION, WITHOUT MENTION OF GANGRENE',
    'd_553': 'OTHER HERNIA OF ABDOMINAL CAVITY WITHOUT MENTION OF OBSTRUCTION OR GANGRENE',
    'd_555': 'REGIONAL ENTERITIS',
    'd_556': 'IDIOPATHIC PROCTOCOLITIS',
    'd_557': 'VASCULAR INSUFFICIENCY OF INTESTINE',
    'd_558': 'OTHER NONINFECTIVE GASTROENTERITIS AND COLITIS',
    'd_560': 'INTESTINAL OBSTRUCTION WITHOUT MENTION OF HERNIA',
    'd_562': 'DIVERTICULA OF INTESTINE',
    'd_564': 'FUNCTIONAL DIGESTIVE DISORDERS, NOT ELSEWHERE CLASSIFIED',
    'd_565': 'ANAL FISSURE AND FISTULA',
    'd_566': 'ABSCESS OF ANAL AND RECTAL REGIONS',
    'd_567': 'PERITONITIS',
    'd_568': 'OTHER DISORDERS OF PERITONEUM',
    'd_569': 'OTHER DISORDERS OF INTESTINE',
    'd_570': 'ACUTE AND SUBACUTE NECROSIS OF LIVER',
    'd_571': 'CHRONIC LIVER DISEASE AND CIRRHOSIS',
    'd_572': 'LIVER ABSCESS AND SEQUELAE OF CHRONIC LIVER DISEASE',
    'd_573': 'OTHER DISORDERS OF LIVER',
    'd_574': 'CHOLELITHIASIS',
    'd_575': 'OTHER DISORDERS OF GALLBLADDER',
    'd_576': 'OTHER DISORDERS OF BILIARY TRACT',
    'd_577': 'DISEASES OF PANCREAS',
    'd_578': 'GASTROINTESTINAL HAEMORRHAGE',
    'd_579': 'INTESTINAL MALABSORPTION',
    'd_580': 'ACUTE GLOMERULONEPHRITIS',
    'd_581': 'NEPHROTIC SYNDROME',
    'd_582': 'CHRONIC GLOMERULONEPHRITIS',
    'd_583': 'NEPHRITIS AND NEPHROPATHY, NOT SPECIFIED AS ACUTE OR CHRONIC',
    'd_584': 'ACUTE RENAL FAILURE',
    'd_585': 'CHRONIC RENAL FAILURE',
    'd_586': 'RENAL FAILURE, UNSPECIFIED',
    'd_587': 'RENAL SCLEROSIS, UNSPECIFIED',
    'd_588': 'DISORDERS RESULTING FROM IMPAIRED RENAL FUNCTION',
    'd_589': 'SMALL KIDNEY OF UNKNOWN CAUSE',
    'd_590': 'INFECTIONS OF KIDNEY',
    'd_591': 'HYDRONEPHROSIS',
    'd_592': 'CALCULUS OF KIDNEY AND URETER',
    'd_593': 'OTHER DISORDERS OF KIDNEY AND URETER',
    'd_594': 'CALCULUS OF LOWER URINARY TRACT',
    'd_595': 'CYSTITIS',
    'd_596': 'OTHER DISORDERS OF BLADDER',
    'd_597': 'URETHRITIS, NOT SEXUALLY TRANSMITTED, AND URETHRAL SYNDROME',
    'd_598': 'URETHRAL STRICTURE',
    'd_599': 'OTHER DISORDERS OF URETHRA AND URINARY TRACT',
    'd_600': 'HYPERPLASIA OF PROSTATE',
    'd_601': 'INFLAMMATORY DISEASES OF PROSTATE',
    'd_602': 'OTHER DISORDERS OF PROSTATE',
    'd_603': 'HYDROCELE',
    'd_604': 'ORCHITIS AND EPIDIDYMITIS',
    'd_605': 'REDUNDANT PREPUCE AND PHIMOSIS',
    'd_606': 'INFERTILITY, MALE',
    'd_607': 'DISORDERS OF PENIS',
    'd_608': 'OTHER DISORDERS OF MALE GENITAL ORGANS',
    'd_610': 'BENIGN MAMMARY DYSPLASIAS',
    'd_611': 'OTHER DISORDERS OF BREAST',
    'd_614': 'INFLAMMATORY DISEASE OF OVARY, FALLOPIAN TUBE, PELVIC CELLULAR TISSUE AND PERITONEUM',
    'd_615': 'INFLAMMATORY DISEASES OF UTERUS, NOT ELSEWHERE CLASSIFIED',
    'd_616': 'INFLAMMATORY DISEASE OF CERVIX, VAGINA AND VULVA',
    'd_617': 'ENDOMETRIOSIS',
    'd_618': 'GENITAL PROLAPSE',
    'd_619': 'FISTULAE INVOLVING FEMALE GENITAL TRACT',
    'd_620': 'NONINFLAMMATORY DISORDERS OF OVARY, FALLOPIAN TUBE AND BROAD LIGAMENT',
    'd_621': 'DISORDERS OF UTERUS, NOT ELSEWHERE CLASSIFIED',
    'd_622': 'NONINFLAMMATORY DISORDERS OF CERVIX',
    'd_623': 'NONINFLAMMATORY DISORDERS OF VAGINA',
    'd_624': 'NONINFLAMMATORY DISORDERS OF VULVA AND PERINEUM',
    'd_625': 'PAIN AND OTHER SYMPTOMS ASSOCIATED WITH FEMALE GENITAL ORGANS',
    'd_626': 'DISORDERS OF MENSTRUATION AND OTHER ABNORMAL BLEEDING FROM FEMALE GENITAL TRACT',
    'd_627': 'MENOPAUSAL AND POSTMENOPAUSAL DISORDERS',
    'd_628': 'INFERTILITY, FEMALE',
    'd_629': 'OTHER DISORDERS OF FEMALE GENITAL ORGANS',
    'd_630': 'HYDATIDIFORM MOLE',
    'd_631': 'OTHER ABNORMAL PRODUCT OF CONCEPTION',
    'd_632': 'MISSED ABORTION',
    'd_633': 'ECTOPIC PREGNANCY',
    'd_634': 'SPONTANEOUS ABORTION',
    'd_635': 'LEGALLY INDUCED ABORTION',
    'd_636': 'ILLEGALLY INDUCED ABORTION',
    'd_637': 'UNSPECIFIED ABORTION',
    'd_638': 'FAILED ATTEMPTED ABORTION',
    'd_639': 'COMPLICATIONS FOLLOWING ABORTION AND ECTOPIC AND MOLAR PREGNANCIES',
    'd_640': 'HAEMORRHAGE IN EARLY PREGNANCY',
    'd_641': 'ANTEPARTUM HAEMORRHAGE, ABRUPTIO PLACENTAE, AND PLACENTA PRAEVIA',
    'd_642': 'HYPERTENSION COMPLICATING PREGNANCY, CHILDBIRTH AND THE PUERPERIUM',
    'd_643': 'EXCESSIVE VOMITING IN PREGNANCY',
    'd_644': 'EARLY OR THREATENED LABOUR',
    'd_645': 'PROLONGED PREGNANCY',
    'd_646': 'OTHER COMPLICATIONS OF PREGNANCY, NOT ELSEWHERE CLASSIFIED',
    'd_647': 'INFECTIVE AND PARASITIC CONDITIONS IN THE MOTHER CLASSIFIABLE ELSEWHERE BUT COMPLICATING PREGNANCY, CHILDBIRTH AND THE PUERPERIUM',
    'd_648': 'OTHER CURRENT CONDITIONS IN THE MOTHER CLASSIFIABLE ELSEWHERE BUT COMPLICATING PREGNANCY, CHILDBIRTH AND THE PUERPERIUM',
    'd_650': 'DELIVERY IN A COMPLETELY NORMAL CASE',
    'd_651': 'MULTIPLE GESTATION',
    'd_652': 'MALPOSITION AND MALPRESENTATION OF FETUS',
    'd_653': 'DISPROPORTION',
    'd_654': 'ABNORMALITY OF ORGANS AND SOFT TISSUES OF PELVIS',
    'd_655': 'KNOWN OR SUSPECTED FETAL ABNORMALITY AFFECTING MANAGEMENT OF MOTHER',
    'd_656': 'OTHER FETAL AND PLACENTAL PROBLEMS AFFECTING MANAGEMENT OF MOTHER',
    'd_657': 'POLYHYDRAMNIOS',
    'd_658': 'OTHER PROBLEMS ASSOCIATED WITH AMNIOTIC CAVITY AND MEMBRANES',
    'd_659': 'OTHER INDICATIONS FOR CARE OR INTERVENTION RELATED TO LABOUR AND DELIVERY AND NOT ELSEWHERE CLASSIFIED',
    'd_660': 'OBSTRUCTED LABOUR',
    'd_661': 'ABNORMALITY OF FORCES OF LABOUR',
    'd_662': 'LONG LABOUR',
    'd_663': 'UMBILICAL CORD COMPLICATIONS',
    'd_664': 'TRAUMA TO PERINEUM AND VULVA DURING DELIVERY',
    'd_665': 'OTHER OBSTETRICAL TRAUMA',
    'd_666': 'POSTPARTUM HAEMORRHAGE',
    'd_667': 'RETAINED PLACENTA OR MEMBRANES, WITHOUT HAEMORRHAGE',
    'd_668': 'COMPLICATIONS OF THE ADMINISTRATION OF ANAESTHETIC OR OTHER SEDATION IN LABOUR AND DELIVERY',
    'd_669': 'OTHER COMPLICATIONS OF LABOUR AND DELIVERY, NOT ELSEWHERE CLASSIFIED',
    'd_670': 'MAJOR PUERPERAL INFECTION',
    'd_671': 'VENOUS COMPLICATIONS IN PREGNANCY AND THE PUERPERIUM',
    'd_672': 'PYREXIA OF UNKNOWN ORIGIN DURING THE PUERPERIUM',
    'd_673': 'OBSTETRICAL PULMONARY EMBOLISM',
    'd_674': 'OTHER AND UNSPECIFIED COMPLICATIONS OF THE PUERPERIUM, NOT ELSEWHERE CLASSIFIED',
    'd_675': 'INFECTIONS OF THE BREAST AND NIPPLE ASSOCIATED WITH CHILDBIRTH',
    'd_676': 'OTHER DISORDERS OF THE BREAST ASSOCIATED WITH CHILDBIRTH, AND DISORDERS OF LACTATION',
    'd_680': 'CARBUNCLE AND FURUNCLE',
    'd_681': 'CELLULITIS AND ABSCESS OF FINGER AND TOE',
    'd_682': 'OTHER CELLULITIS AND ABSCESS',
    'd_683': 'ACUTE LYMPHADENITIS',
    'd_684': 'IMPETIGO',
    'd_685': 'PILONIDAL CYST',
    'd_686': 'OTHER LOCAL INFECTIONS OF SKIN AND SUBCUTANEOUS TISSUE',
    'd_690': 'ERYTHEMATOSQUAMOUS DERMATOSIS',
    'd_691': 'ATOPIC DERMATITIS AND RELATED CONDITIONS',
    'd_692': 'CONTACT DERMATITIS AND OTHER ECZEMA',
    'd_693': 'DERMATITIS DUE TO SUBSTANCES TAKEN INTERNALLY',
    'd_694': 'BULLOUS DERMATOSES',
    'd_695': 'ERYTHEMATOUS CONDITIONS',
    'd_696': 'PSORIASIS AND SIMILAR DISORDERS',
    'd_697': 'LICHEN',
    'd_698': 'PRURITIS AND RELATED CONDITIONS',
    'd_700': 'CORNS AND CALLOSITIES',
    'd_701': 'OTHER HYPERTROPHIC AND ATROPHIC CONDITIONS OF SKIN',
    'd_702': 'OTHER DERMATOSES',
    'd_703': 'DISEASES OF NAIL',
    'd_704': 'DISEASES OF HAIR AND HAIR FOLLICLES',
    'd_705': 'DISORDERS OF SWEAT GLANDS',
    'd_706': 'DISEASES OF SEBACEOUS GLANDS',
    'd_707': 'CHRONIC ULCER OF SKIN',
    'd_708': 'URTICARIA',
    'd_709': 'OTHER DISORDERS OF SKIN AND SUBCUTANEOUS TISSUE',
    'd_710': 'DIFFUSE DISEASES OF CONNECTIVE TISSUE',
    'd_711': 'ARTHROPATHY ASSOCIATED WITH INFECTIONS',
    'd_712': 'CRYSTAL ARTHROPATHIES',
    'd_713': 'ARTHROPATHY ASSOCIATED WITH OTHER DISORDERS CLASSIFIED ELSEWHERE',
    'd_714': 'RHEUMATOID ARTHRITIS AND OTHER INFLAMMATORY POLYARTHROPATHIES',
    'd_715': 'OSTEOARTHROSIS AND ALLIED DISORDERS',
    'd_716': 'OTHER AND UNSPECIFIED ARTHROPATHIES',
    'd_717': 'INTERNAL DERANGEMENT OF KNEE',
    'd_718': 'OTHER DERANGEMENT OF JOINT',
    'd_719': 'OTHER AND UNSPECIFIED DISORDER OF JOINT',
    'd_720': 'ANKYLOSING SPONDYLITIS AND OTHER INFLAMMATORY SPONDYLOPATHIES',
    'd_721': 'SPONDYLOSIS AND ALLIED DISORDERS',
    'd_722': 'INTERVERTEBRAL DISC DISORDERS',
    'd_723': 'OTHER DISORDERS OF CERVICAL REGION',
    'd_724': 'OTHER AND UNSPECIFIED DISORDERS OF BACK',
    'd_725': 'POLYMYALGIA RHEUMATICA',
    'd_726': 'PERIPHERAL ENTHESOPATHIES AND ALLIED SYNDROMES',
    'd_727': 'OTHER DISORDERS OF SYNOVIUM, TENDON AND BURSA',
    'd_728': 'DISORDERS OF MUSCLE, LIGAMENT AND FASCIA',
    'd_729': 'OTHER DISORDERS OF SOFT TISSUES',
    'd_730': 'OSTEOMYELITIS, PERIOSTITIS AND OTHER INFECTIONS INVOLVING BONE',
    'd_731': 'OSTEITIS DEFORMANS AND OSTEOPATHIES ASSOCIATED WITH OTHER DISORDERS',
    'd_732': 'OSTEOCHONDROPATHIES',
    'd_733': 'OTHER DISORDERS OF BONE AND CARTILAGE',
    'd_734': 'FLAT FOOT',
    'd_735': 'ACQUIRED DEFORMITIES OF TOE',
    'd_736': 'OTHER ACQUIRED DEFORMITIES OF LIMBS',
    'd_737': 'CURVATURE OF SPINE',
    'd_738': 'OTHER ACQUIRED DEFORMITY',
    'd_739': 'ABDOMEN AND OTHER',
    'd_740': 'ANENCEPHALUS AND SIMILAR ANOMALIES',
    'd_741': 'SPINA BIFIDA',
    'd_742': 'OTHER CONGENITAL ANOMALIES OF NERVOUS SYSTEM',
    'd_743': 'CONGENITAL ANOMALIES OF EYE',
    'd_744': 'CONGENITAL ANOMALIES OF EAR, FACE AND NECK',
    'd_745': 'BULBUS CORDIS ANOMALIES AND ANOMALIES OF CARDIAC SEPTAL CLOSURE',
    'd_746': 'OTHER CONGENITAL ANOMALIES OF HEART',
    'd_747': 'OTHER CONGENITAL ANOMALIES OF CIRCULATORY SYSTEM',
    'd_748': 'CONGENITAL ANOMALIES OF RESPIRATORY SYSTEM',
    'd_749': 'CLEFT PALATE AND CLEFT LIP',
    'd_750': 'OTHER CONGENITAL ANOMALIES OF UPPER ALIMENTARY TRACT',
    'd_751': 'OTHER CONGENITAL ANOMALIES OF DIGESTIVE SYSTEM',
    'd_752': 'CONGENITAL ANOMALIES OF GENITAL ORGANS',
    'd_753': 'CONGENITAL ANOMALIES OF URINARY SYSTEM',
    'd_754': 'CERTAIN CONGENITAL MUSCULOSKELETAL DEFORMITIES',
    'd_755': 'OTHER CONGENITAL ANOMALIES OF LIMBS',
    'd_756': 'OTHER CONGENITAL MUSCULOSKELETAL ANOMALIES',
    'd_757': 'CONGENITAL ANOMALIES OF THE INTEGUMENT',
    'd_758': 'CHROMOSOMAL ANOMALIES',
    'd_759': 'OTHER AND UNSPECIFIED CONGENITAL ANOMALIES',
    'd_760': 'FETUS OR NEWBORN AFFECTED BY MATERNAL CONDITIONS WHICH MAY BE UNRELATED TO PRESENT PREGNANCY',
    'd_761': 'FETUS OR NEWBORN AFFECTED BY MATERNAL COMPLICATIONS OF PREGNANCY',
    'd_762': 'FETUS OR NEWBORN AFFECTED BY COMPLICATIONS OF PLACENTA, CORD AND MEMBRANES',
    'd_763': 'FETUS OR NEWBORN AFFECTED BY OTHER COMPLICATIONS OF LABOUR AND DELIVERY',
    'd_764': 'SLOW FETAL GROWTH AND FETAL MALNUTRITION',
    'd_765': 'DISORDERS RELATING TO SHORT GESTATION AND UNSPECIFIED LOW BIRTHWEIGHT',
    'd_766': 'DISORDERS RELATING TO LONG GESTATION AND HIGH BIRTHWEIGHT',
    'd_767': 'BIRTH TRAUMA',
    'd_768': 'INTRAUTERINE HYPOXIA AND BIRTH ASPHYXIA',
    'd_769': 'RESPIRATORY DISTRESS SYNDROME',
    'd_770': 'OTHER RESPIRATORY CONDITIONS OF FETUS AND NEWBORN',
    'd_771': 'INFECTIONS SPECIFIC TO THE PERINATAL PERIOD',
    'd_772': 'FETAL AND NEONATAL HAEMORRHAGE',
    'd_773': 'HAEMOLYTIC DISEASE OF FETUS OR NEWBORN, DUE TO ISOIMMUNIZATION',
    'd_774': 'OTHER PERINATAL JAUNDICE',
    'd_775': 'ENDOCRINE AND METABOLIC DISTURBANCES SPECIFIC TO THE FETUS AND NEWBORN',
    'd_776': 'HAEMATOLOGICAL DISORDERS OF FETUS AND NEWBORN',
    'd_777': 'PERINATAL DISORDERS OF DIGESTIVE SYSTEM',
    'd_778': 'CONDITIONS INVOLVING THE INTEGUMENT AND TEMPERATURE REGULATION OF FETUS AND NEWBORN',
    'd_779': 'OTHER AND ILL-DEFINED CONDITIONS ORIGINATING IN THE PERINATAL PERIOD',
    'd_780': 'GENERAL SYMPTOMS',
    'd_781': 'SYMPTOMS INVOLVING NERVOUS AND MUSCULOSKELETAL SYSTEMS',
    'd_782': 'SYMPTOMS INVOLVING SKIN AND OTHER INTEGUMENTARY TISSUE',
    'd_783': 'SYMPTOMS CONCERNING NUTRITION, METABOLISM AND DEVELOPMENT',
    'd_784': 'SYMPTOMS INVOLVING HEAD AND NECK',
    'd_785': 'SYMPTOMS INVOLVING CARDIOVASCULAR SYSTEM',
    'd_786': 'SYMPTOMS INVOLVING RESPIRATORY SYSTEM AND OTHER CHEST SYMPTOMS',
    'd_787': 'SYMPTOMS INVOLVING DIGESTIVE SYSTEM',
    'd_788': 'SYMPTOMS INVOLVING URINARY SYSTEM',
    'd_789': 'OTHER SYMPTOMS INVOLVING ABDOMEN AND PELVIS',
    'd_790': 'NONSPECIFIC FINDINGS ON EXAMINATION OF BLOOD',
    'd_791': 'NONSPECIFIC FINDINGS ON EXAMINATION OF URINE',
    'd_792': 'NONSPECIFIC ABNORMAL FINDINGS IN OTHER BODY SUBSTANCES',
    'd_793': 'NONSPECIFIC ABNORMAL FINDINGS ON RADIOLOGICAL AND OTHER EXAMINATION OF BODY STRUCTURE',
    'd_794': 'NONSPECIFIC ABNORMAL RESULTS OF FUNCTION STUDIES',
    'd_795': 'NONSPECIFIC ABNORMAL HISTOLOGICAL AND IMMUNOLOGICAL FINDINGS',
    'd_796': 'OTHER NONSPECIFIC ABNORMAL FINDINGS',
    'd_797': 'SENILITY WITHOUT MENTION OF PSYCHOSIS',
    'd_798': 'SUDDEN DEATH, CAUSE UNKNOWN',
    'd_799': 'OTHER ILL-DEFINED AND UNKNOWN CAUSES OF MORBIDITY AND MORTALITY',
    'd_800': 'FRACTURE OF VAULT OF SKULL',
    'd_801': 'FRACTURE OF BASE OF SKULL',
    'd_802': 'FRACTURE OF FACE BONES',
    'd_803': 'OTHER AND UNQUALIFIED SKULL FRACTURES',
    'd_804': 'MULTIPLE FRACTURES INVOLVING SKULL OR FACE WITH OTHER BONES',
    'd_805': 'FRACTURE OF VERTEBRAL COLUMN WITHOUT MENTION OF SPINAL CORD LESION',
    'd_806': 'FRACTURE OF VERTEBRAL COLUMN WITH SPINAL CORD LESION',
    'd_807': 'FRACTURE OF RIB(S), STERNUM, LARYNX AND TRACHEA',
    'd_808': 'FRACTURE OF PELVIS',
    'd_809': 'ILL-DEFINED FRACTURES OF TRUNK',
    'd_810': 'FRACTURE OF CLAVICLE',
    'd_811': 'FRACTURE OF SCAPULA',
    'd_812': 'FRACTURE OF HUMERUS',
    'd_813': 'FRACTURE OF RADIUS AND ULNA',
    'd_814': 'FRACTURE OF CARPAL BONE(S)',
    'd_815': 'FRACTURE OF METACARPAL BONE(S)',
    'd_816': 'FRACTURE OF ONE OR MORE PHALANGES OF HAND',
    'd_817': 'MULTIPLE FRACTURES OF HAND BONES',
    'd_818': 'ILL-DEFINED FRACTURES OF UPPER LIMB',
    'd_819': 'MULTIPLE FRACTURES INVOLVING BOTH UPPER LIMBS, AND UPPER LIMB WITH RIB(S) AND STERNUM',
    'd_820': 'FRACTURE OF NECK OF FEMUR',
    'd_821': 'FRACTURE OF OTHER AND UNSPECIFIED PARTS OF FEMUR',
    'd_822': 'FRACTURE OF PATELLA',
    'd_823': 'FRACTURE OF TIBIA AND FIBULA',
    'd_824': 'FRACTURE OF ANKLE',
    'd_825': 'FRACTURE OF ONE OR MORE TARSAL AND METATARSAL BONES',
    'd_826': 'FRACTURE OF ONE OR MORE PHALANGES OF FOOT',
    'd_827': 'OTHER, MULTIPLE AND ILL-DEFINED FRACTURES OF LOWER LIMB',
    'd_828': 'MULTIPLE FRACTURES INVOLVING BOTH LOWER LIMBS, LOWER WITH UPPER LIMB, AND LOWER LIMB(S) WITH RIB(S) AND STERNUM',
    'd_829': 'FRACTURE OF UNSPECIFIED BONES',
    'd_830': 'DISLOCATION OF JAW',
    'd_831': 'DISLOCATION OF SHOULDER',
    'd_832': 'DISLOCATION OF ELBOW',
    'd_833': 'DISLOCATION OF WRIST',
    'd_834': 'DISLOCATION OF FINGER',
    'd_835': 'DISLOCATION OF HIP',
    'd_836': 'DISLOCATION OF KNEE',
    'd_837': 'DISLOCATION OF ANKLE',
    'd_838': 'DISLOCATION OF FOOT',
    'd_839': 'OTHER, MULTIPLE AND ILL-DEFINED DISLOCATIONS',
    'd_840': 'SPRAINS AND STRAINS OF SHOULDER AND UPPER ARM',
    'd_841': 'SPRAINS AND STRAINS OF ELBOW AND FOREARM',
    'd_842': 'SPRAINS AND STRAINS OF WRIST AND HAND',
    'd_843': 'SPRAINS AND STRAINS OF HIP AND THIGH',
    'd_844': 'SPRAINS AND STRAINS OF KNEE AND LEG',
    'd_845': 'SPRAINS AND STRAINS OF ANKLE AND FOOT',
    'd_846': 'SPRAINS AND STRAINS OF SACROILIAC REGION',
    'd_847': 'SPRAINS AND STRAINS OF OTHER AND UNSPECIFIED PARTS OF BACK',
    'd_848': 'OTHER AND ILL-DEFINED SPRAINS AND STRAINS',
    'd_850': 'CONCUSSION',
    'd_851': 'CEREBRAL LACERATION AND CONTUSION',
    'd_852': 'SUBARACHNOID, SUBDURAL AND EXTRADURAL HAEMORRHAGE, FOLLOWING INJURY',
    'd_853': 'OTHER AND UNSPECIFIED INTRACRANIAL HAEMORRHAGE FOLLOWING INJURY',
    'd_854': 'INTRACRANIAL INJURY OF OTHER AND UNSPECIFIED NATURE',
    'd_860': 'TRAUMATIC PNEUMOTHORAX AND HAEMOTHORAX',
    'd_861': 'PNEUMOTHORAX WITHOUT MENTION OF OPEN WOUND INTO THORAX',
    'd_862': 'INJURY TO HEART AND LUNG',
    'd_863': 'INJURY TO GASTROINTESTINAL TRACT',
    'd_864': 'INJURY TO LIVER',
    'd_865': 'INJURY TO SPLEEN',
    'd_866': 'INJURY TO KIDNEY',
    'd_867': 'INJURY TO PELVIC ORGANS',
    'd_868': 'INJURY TO OTHER INTRAABDOMINAL ORGANS',
    'd_869': 'INTERNAL INJURY TO UNSPECIFIED OR ILL-DEFINED ORGANS',
    'd_870': 'OPEN WOUND OF HEAD, NECK AND TRUNK',
    'd_871': 'OPEN WOUND OF EYEBALL',
    'd_872': 'OPEN WOUND OF EAR',
    'd_873': 'OTHER OPEN WOUND OF HEAD',
    'd_874': 'OPEN WOUND OF NECK',
    'd_875': 'OPEN WOUND OF CHEST (WALL)',
    'd_876': 'OPEN WOUND OF BACK',
    'd_877': 'OPEN WOUND OF BUTTUCK',
    'd_878': 'OPEN WOUND OF GENITAL ORGANS (EXTERNAL), INCLUDING TRAUMATIC AMPUTATION',
    'd_879': 'OTHER AND UNSPECIFIED OPEN WOUND OF HEAD, NECK AND TRUNK',
    'd_880': 'OPEN WOUND OF SHOULDER AND UPPER ARM',
    'd_881': 'OPEN WOUND OF ELBOW, FOREARM AND WRIST',
    'd_882': 'OPEN WOUND OF HAND EXCEPT FINGER(S) ALONE',
    'd_883': 'OPEN WOUND OF FINGER(S)',
    'd_884': 'MULTIPLE AND UNSPECIFIED OPEN WOUND OF UPPER LIMB',
    'd_885': 'TRAUMATIC AMPUTATION OF THUMB (COMPLETE) (PARTIAL)',
    'd_886': 'TRAUMATIC AMPUTATION OF OTHER FINGER(S) (COMPLETE) (PARTIAL)',
    'd_887': 'TRAUMATIC AMPUTATION OF ARM AND HAND (COMPLETE) (PARTIAL)',
    'd_890': 'OPEN WOUND OF HIP AND THIGH',
    'd_891': 'OPEN WOUND OF KNEE, LEG (EXCEPT THIGH) AND ANKLE',
    'd_892': 'OPEN WOUND OF FOOT EXCEPT TOE(S) ALONE',
    'd_893': 'OPEN WOUND OF TOE(S)',
    'd_894': 'MULTIPLE AND UNSPECIFIED OPEN WOUND OF LOWER LIMB',
    'd_895': 'TRAUMATIC AMPUTATION OF TOE(S) (COMPLETE) (PARTIAL)',
    'd_896': 'TRAUMATIC AMPUTATION OF FOOT (COMPLETE) (PARTIAL)',
    'd_897': 'TRAUMATIC AMPUTATION OF LEG(S) (COMPLETE) (PARTIAL)',
    'd_900': 'INJURY TO BLOOD VESSELS OF HEAD AND NECK',
    'd_901': 'INJURY TO BLOOD VESSELS OF THORAX',
    'd_902': 'INJURY TO BLOOD VESSELS OF ABDOMEN AND PELVIS',
    'd_903': 'INJURY TO BLOOD VESSELS OF UPPER EXTREMITY',
    'd_904': 'INJURY TO BLOOD VESSELS OF LOWER EXTREMITY AND UNSPECIFIED SITES',
    'd_905': 'LATE EFFECTS OF MUSCULOSKELETAL AND CONNECTIVE TISSUE INJURIES',
    'd_906': 'LATE EFFECTS OF INJURIES TO SKIN AND SUBCUTANEOUS TISSUES',
    'd_907': 'LATE EFFECTS OF INJURIES TO THE NERVOUS SYSTEM',
    'd_908': 'LATE EFFECTS OF OTHER AND UNSPECIFIED EXTERNAL CAUSES',
    'd_909': 'LATE EFFECTS OF POISONING AND TOXIC EFFECTS',
    'd_910': 'SUPERFICIAL INJURY OF FACE, NECK AND SCALP EXCEPT EYE',
    'd_911': 'SUPERFICIAL INJURY OF TRUNK',
    'd_912': 'SUPERFICIAL INJURY OF SHOULDER AND UPPER ARM',
    'd_913': 'SUPERFICIAL INJURY OF ELBOW, FOREARM AND WRIST',
    'd_914': 'SUPERFICIAL INJURY OF HAND(S) EXCEPT FINGER(S) ALONE',
    'd_915': 'SUPERFICIAL INJURY OF FINGER(S)',
    'd_916': 'SUPERFICIAL INJURY OF HIP, THIGH, LEG AND ANKLE',
    'd_917': 'SUPERFICIAL INJURY OF FOOT AND TOE(S)',
    'd_918': 'SUPERFICIAL INJURY OF EYE AND ADNEXA',
    'd_919': 'SUPERFICIAL INJURY OF OTHER, MULTIPLE AND UNSPECIFIED SITES',
    'd_920': 'CONTUSION OF FACE, SCALP, AND NECK EXCEPT EYE(S)',
    'd_921': 'CONTUSION OF EYE AND ADNEXA',
    'd_922': 'CONTUSION OF TRUNK',
    'd_923': 'CONTUSION OF UPPER LIMB',
    'd_924': 'CONTUSION OF LOWER LIMB AND OF OTHER AND UNSPECIFIED SITES',
    'd_925': 'CRUSHING INJURY OF FACE, SCALP AND NECK',
    'd_926': 'CRUSHING INJURY OF TRUNK',
    'd_927': 'CRUSHING INJURY OF UPPER LIMB',
    'd_928': 'CRUSHING INJURY OF LOWER LIMB',
    'd_929': 'CRUSHING INJURY OF MULTIPLE AND UNSPECIFIED SITES',
    'd_930': 'EFFECTS OF FOREIGN BODY ENTERING THROUGH ORIFICE OF EYE',
    'd_931': 'FOREIGN BODY IN EAR',
    'd_932': 'FOREIGN BODY IN NOSE',
    'd_933': 'FOREIGN BODY IN PHARYNX AND LARYNX',
    'd_934': 'FOREIGN BODY IN TRACHEA, BRONCHUS AND LUNG',
    'd_935': 'FOREIGN BODY IN MOUTH, OESOPHAGUS AND STOMACH',
    'd_936': 'FOREIGN BODY IN INTESTINE AND COLON',
    'd_937': 'FOREIGN BODY IN ANUS AND RECTUM',
    'd_938': 'FOREIGN BODY IN DIGESTIVE SYSTEM, UNSPECIFIED',
    'd_939': 'FOREIGN BODY IN GENITOURINARY TRACT',
    'd_940': 'BURN CONFINED TO EYE AND ADNEXA',
    'd_941': 'BURN OF FACE, HEAD AND NECK',
    'd_942': 'BURN OF TRUNK',
    'd_943': 'BURN OF UPPER LIMB, EXCEPT WRIST AND HAND',
    'd_944': 'BURN OF WRIST(S) AND HAND(S)',
    'd_945': 'BURN OF LOWER LIMB(S)',
    'd_946': 'BURNS OF MULTIPLE SPECIFIED SITES',
    'd_947': 'BURN OF INTERNAL ORGANS',
    'd_948': 'BURNS CLASSIFIED ACCORDING TO EXTENT OF BODY SURFACE INVOLVED',
    'd_949': 'BURN, UNSPECIFIED',
    'd_950': 'INJURY TO OPTIC NERVE AND PATHWAYS',
    'd_951': 'INJURY TO OTHER CRANIAL NERVE(S)',
    'd_952': 'SPINAL CORD LESION WITHOUT EVIDENCE OF SPINAL BONE INJURY',
    'd_953': 'INJURY TO NERVE ROOTS AND SPINAL PLEXUS',
    'd_954': 'INJURY TO OTHER NERVE(S) OF TRUNK EXCLUDING SHOULDER AND PELVIC GIRDLES',
    'd_955': 'INJURY TO PERIPHERAL NERVE(S) OF SHOULDER GIRDLE AND UPPER LIMB',
    'd_956': 'INJURY TO PERIPHERAL NERVE(S) OF PELVIC GIRDLE AND LOWER LIMB',
    'd_957': 'INJURY TO OTHER AND UNSPECIFIED NERVES',
    'd_958': 'CERTAIN TRAUMATIC COMPLICATIONS',
    'd_959': 'INJURY, OTHER AND UNSPECIFIED',
    'd_960': 'POISONING BY ANTIBIOTICS',
    'd_961': 'POISONING BY OTHER ANTI-INFECTIVES',
    'd_962': 'POISONING BY HORMONES AND SYNTHETIC SUBSTANCES',
    'd_963': 'POISONING BY PRIMARILY SYSTEMIC AGENTS',
    'd_964': 'POISONING BY AGENTS PRIMARILY AFFECTING BLOOD CONSTITUENTS',
    'd_965': 'POISONING BY ANALGESICS, ANTIPYRETICS AND ANTIRHEUMATICS',
    'd_966': 'POISONING BY ANTICONVULSANTS AND ANTI-PARKINSONISM DRUGS',
    'd_967': 'POISONING BY SEDATIVES AND HYPNOTICS',
    'd_968': 'POISONING BY OTHER CENTRAL NERVOUS SYSTEM DEPRESSANTS',
    'd_969': 'POISONING BY PSYCHOTROPIC AGENTS',
    'd_970': 'POISONING BY CENTRAL NERVOUS SYSTEM STIMULANTS',
    'd_971': 'POISONING BY AGENTS PRIMARILY AFFECTING THE AUTONOMIC NERVOUS SYSTEM',
    'd_972': 'POISONING BY AGENTS PRIMARILY AFFECTING THE CARDIOVASCULAR SYSTEM',
    'd_973': 'POISONING BY AGENTS PRIMARILY AFFECTING THE GASTROINTESTINAL SYSTEM',
    'd_974': 'POISONING BY WATER, MINERAL AND URIC ACID METABOLISM DRUGS',
    'd_975': 'POISONING BY AGENTS PRIMARILY ACTING ON THE SMOOTH AND SKELETAL MUSCLES',
    'd_976': 'POISONING BY AGENTS PRIMARILY AFFECTING SKIN AND MUCOUS MEMBRANE',
    'd_977': 'POISONING BY OTHER AND UNSPECIFIED DRUGS AND MEDICAMENTS',
    'd_978': 'POISONING BY BACTERIAL VACCINES',
    'd_979': 'POISONING BY OTHER AND UNSPECIFIED VACCINES AND BIOLOGICAL SUBSTANCES',
    'd_980': 'TOXIC EFFECT OF ALCOHOL',
    'd_981': 'TOXIC EFFECT OF PETROLEUM PRODUCTS',
    'd_982': 'TOXIC EFFECT OF SOLVENTS OTHER THAN PETROLEUM-BASED',
    'd_983': 'TOXIC EFFECT OF CORROSIVE AROMATICS, ACIDS AND CAUSTIC ALKALIS',
    'd_984': 'TOXIC EFFECT OF LEAD AND ITS COMPOUNDS',
    'd_985': 'TOXIC EFFECT OF OTHER METALS',
    'd_986': 'TOXIC EFFECT OF CARBON MONOXIDE',
    'd_987': 'TOXIC EFFECT OF OTHER GASES, FUMES OR VAPOURS',
    'd_988': 'TOXIC EFFECT OF NOXIOUS SUBSTANCES EATEN AS FOOD',
    'd_989': 'TOXIC EFFECT OF OTHER AND UNSPECIFIED SUBSTANCES',
    'd_990': 'EFFECTS OF RADIATION, UNSPECIFIED',
    'd_991': 'EFFECTS OF REDUCED TEMPERATURE',
    'd_992': 'EFFECTS OF HEAT AND LIGHT',
    'd_993': 'EFFECTS OF AIR PRESSURE',
    'd_994': 'EFFECTS OF OTHER EXTERNAL CAUSES',
    'd_995': 'CERTAIN ADVERSE EFFECTS NOT ELSEWHERE CLASSIFIED',
    'd_996': 'COMPLICATIONS PECULIAR TO CERTAIN SPECIFIED PROCEDURES',
    'd_997': 'COMPLICATIONS AFFECTING SPECIFIED BODY SYSTEMS, NOT ELSEWHERE CLASSIFIED',
    'd_998': 'OTHER COMPLICATIONS OF PROCEDURES, NOT ELSEWHERE CLASSIFIED',
    'd_999': 'COMPLICATIONS OF MEDICAL CARE, NOT ELSEWHERE CLASSIFIED',
}
